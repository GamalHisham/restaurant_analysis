# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel('/content/drive/My Drive/Data/restaurant_data.xlsx')

# %%
df.sample(5)
# Out:
#        order_id order_date order_time  item_id        item_name category  \
# 1330       1346 2023-01-10   18:34:14      119    Chicken Torta  Mexican
# 4687       4746 2023-02-04   19:30:52      127     Meat Lasagna  Italian
# 4753       4812 2023-02-05   13:42:50      120      Steak Torta  Mexican
# 2902       2939 2023-01-22   17:44:59      117  Chicken Burrito  Mexican
# 11255     11384 2023-03-26   11:50:45      118    Steak Burrito  Mexican
#
#        Price
# 1330   11.95
# 4687   17.95
# 4753   13.95
# 2902   12.95
# 11255  14.95

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12097 entries, 0 to 12096
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   order_id    12097 non-null  int64
#  1   order_date  12097 non-null  datetime64[ns]
#  2   order_time  12097 non-null  object
#  3   item_id     12097 non-null  int64
#  4   item_name   12097 non-null  object
#  5   category    12097 non-null  object
#  6   Price       12097 non-null  float64
# dtypes: datetime64[ns](1), float64(1), int64(2), object(3)
# memory usage: 661.7+ KB

# %%
df.describe()
# Out:
#            order_id                     order_date       item_id         Price
# count  12097.000000                          12097  12097.000000  12097.000000
# mean    6118.950897  2023-02-14 11:17:33.781929216    115.202282     13.161767
# min        1.000000            2023-01-01 00:00:00    101.000000      5.000000
# 25%     3064.000000            2023-01-23 00:00:00    107.000000     10.500000
# 50%     6119.000000            2023-02-14 00:00:00    114.000000     13.950000
# 75%     9175.000000            2023-03-09 00:00:00    123.000000     16.500000
# max    12234.000000            2023-03-31 00:00:00    132.000000     19.950000
# std     3531.337208                            NaN      9.387580      3.986392

# %%
sns.violinplot(df['Price'],orient='h')
# Out:
# <Axes: xlabel='Price'>
